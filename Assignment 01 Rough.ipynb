# %% [markdown]
# # <u>**Importing libraries**</u>

# %%
import pandas as pd
import numpy as np
import statistics as st

# %%
chronic_diseases = pd.read_csv('chronic_disease.csv')

# %% [markdown]
# ## <u>**a. What are the types of varibles in the dataset?**</u>

# %%
chronic_diseases.head(15)
# Out:
#     Patient_Number  BP_Abnormality  Female  Level_of_Hemoglobin  Age  BMI  \
# 0                1               1       1                11.28   34   23
# 1                2               0       1                 9.75   54   33
# 2                3               1       0                10.79   70   49
# 3                4               0       0                11.00   71   50
# 4                5               1       0                14.17   52   19
# 5                6               0       0                11.64   23   48
# 6                7               1       1                11.69   43   41
# 7                8               0       0                12.70   48   20
# 8                9               0       0                10.88   72   44
# 9               10               1       0                14.56   40   44
# 10              11               1       1                 8.58   70   28
# 11              12               1       0                12.77   35   17
# ...

# %%
chronic_diseases.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 10 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Patient_Number                 2000 non-null   int64
#  1   BP_Abnormality                 2000 non-null   int64
#  2   Female                         2000 non-null   int64
#  3   Level_of_Hemoglobin            2000 non-null   float64
#  4   Age                            2000 non-null   int64
#  5   BMI                            2000 non-null   int64
#  6   Smoking                        2000 non-null   int64
#  7   Steps_Walk_Week                2000 non-null   int64
#  8   Chronic_kidney_disease         2000 non-null   int64
#  9   Adrenal_and_thyroid_disorders  2000 non-null   int64
# dtypes: float64(1), int64(9)
# memory usage: 156.4 KB

# %%
chronic_diseases.tail(15)
# Out:
#       Patient_Number  BP_Abnormality  Female  Level_of_Hemoglobin  Age  BMI  \
# 1985            1986               0       0                10.44   38   31
# 1986            1987               1       1                13.63   49   36
# 1987            1988               1       0                11.79   19   44
# 1988            1989               1       0                17.17   20   48
# 1989            1990               1       0                10.84   20   15
# 1990            1991               1       0                11.21   63   25
# 1991            1992               1       0                15.53   22   24
# 1992            1993               1       1                 9.38   60   39
# 1993            1994               0       1                 9.69   73   42
# 1994            1995               0       1                11.07   58   31
# 1995            1996               1       1                10.14   69   26
# ...

# %% [markdown]
# The **chronic_disease** dataset is a combination of unique, categorical and numerical variables, their explanation is given below:
#
# **1. Patient_Number: A unique identifier for

# %%
chronic_diseases.groupby('Female')['BMI'].describe()
# Out:
#          count       mean        std   min   25%   50%   75%   max
# Female
# 0       1008.0  29.962302  11.795534  10.0  20.0  30.0  40.0  50.0
# 1        992.0  30.202621  11.730934  10.0  20.0  30.0  40.0  50.0

# %%
chronic_diseases.groupby('Female')['BMI'].skew()
# Out:
# Female
# 0   -0.002300
# 1   -0.033004
# Name: BMI, dtype: float64

# %%
chronic_diseases.groupby('Female')['BMI'].apply(pd.Series.kurt)
# Out:
# Female
# 0   -1.207777
# 1   -1.155743
# Name: BMI, dtype: float64

# %%
chronic_diseases.groupby('Female').mean(['Patient_Number'])
# Out:
#         Patient_Number  BP_Abnormality  Level_of_Hemoglobin        Age  \
# Female
# 0           987.043651        0.466270            12.605565  45.575397
# 1          1014.173387        0.521169            10.800060  47.557460
#
#               BMI   Smoking  Steps_Walk_Week  Chronic_kidney_disease  \
# Female
# 0       29.962302  0.509921     25166.897817                0.492063
# 1       30.202621  0.509073     25343.362903                0.518145
#
#         Adrenal_and_thyroid_disorders
# Female
# 0                            0.449405
# 1                            0.437500
